# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = [10, 6]

# %%
data = json.load(open('../results/benchmark_lookup_o2.json'))
benchmarks_raw = pd.DataFrame(data['benchmarks'])
benchmarks_raw.rename({'per_family_instance_index': 'data_size', 'family_index': 'benchmark_name'}, axis=1, inplace=True)
'''
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(0, '1 KB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(1, '10 KB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(2, '100 KB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(3, '1 MB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(4, '10 MB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(5, '100 MB')
benchmarks_raw['data_size'] = benchmarks_raw['data_size'].replace(6, '1 GB')


benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(0, 'BST')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(1, 'SortedVector')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(2, 'SortedOnAccessVector')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(3, 'TreeSet')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(4, 'HashSet')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(5, 'SortedList')
benchmarks_raw['benchmark_name'] = benchmarks_raw['benchmark_name'].replace(6, 'SortedOnAccessList')
'''
benchmarks_raw
# Out:
#          cpu_time  benchmark_name  iterations  \
# 0        0.034079               0       20014
# 1        0.350810               0        2044
# 2        3.399793               0         203
# 3        0.282247               0        2488
# 4        2.947435               0         246
# 5       28.011400               0          25
# 6        2.771629               0         256
# 7       27.491615               0          26
# 8      283.894333               0           3
# 9       33.781350               0          20
# 10     332.229500               0           2
# 11    3351.361000               0           1
# 12     350.702000               0           2
# 13    3791.479000               0           1
# 14   36390.981000               0           1
# 15    7257.572000               0           1
# 16       0.008369               1       78337
# 17       0.089959               1        8275
# 18       0.849074               1         829
# 19       0.017750               1       39060
# 20       0.182627               1        3872
# 21       1.809010               1         390
# 22       0.025164               1       28400
# 23       0.251336               1        2803
# 24       2.420444               1         286
# 25       0.091382               1        7837
# 26       0.923932               1         766
# 27       8.942679               1          78
# 28       0.154561               1        4538
# 29       1.513938               1         455
# ..            ...             ...         ...
# 96      14.947143               4          42
# 97       0.022450               4       32401
# 98       0.226623               4        2787
# 99      11.976283               4          53
# 100      0.227020               5        3141
# 101      2.335582               5         287
# 102     22.503806               5          31
# 103      3.419820               5         206
# 104     34.735381               5          21
# 105    338.501500               5           2
# 106    155.211750               5           4
# 107   1495.507000               5           1
# 108  15679.708000               5           1
# 109   3020.022000               5           1
# 110  28460.124000               5           1
# 111      0.114081               6        5105
# 112      1.296110               6         601
# 113     11.475810               6          58
# 114      1.617706               6         422
# 115     16.360488               6          43
# 116    163.592250               6           4
# 117     18.517256               6          39
# 118    200.960250               6           4
# 119   1824.724000               6           1
# 120    176.021250               6           4
# 121   1754.147000               6           1
# 122  17926.967000               6           1
# 123   3361.801000               6           1
# 124  31663.210000               6           1
# 125  34204.535000               6           1
#
#                                                   name  data_size  \
# 0    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          0
# 1    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          1
# 2    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          2
# 3    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          3
# 4    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          4
# 5    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          5
# 6    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          6
# 7    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          7
# 8    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          8
# 9    LookUpFixture<std::vector>/UnsortedVec_LookUp/...          9
# 10   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         10
# 11   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         11
# 12   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         12
# 13   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         13
# 14   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         14
# 15   LookUpFixture<std::vector>/UnsortedVec_LookUp/...         15
# 16   LookUpFixture<std::vector, SortedOnAccess>/Sor...          0
# 17   LookUpFixture<std::vector, SortedOnAccess>/Sor...          1
# 18   LookUpFixture<std::vector, SortedOnAccess>/Sor...          2
# 19   LookUpFixture<std::vector, SortedOnAccess>/Sor...          3
# 20   LookUpFixture<std::vector, SortedOnAccess>/Sor...          4
# 21   LookUpFixture<std::vector, SortedOnAccess>/Sor...          5
# 22   LookUpFixture<std::vector, SortedOnAccess>/Sor...          6
# 23   LookUpFixture<std::vector, SortedOnAccess>/Sor...          7
# 24   LookUpFixture<std::vector, SortedOnAccess>/Sor...          8
# 25   LookUpFixture<std::vector, SortedOnAccess>/Sor...          9
# 26   LookUpFixture<std::vector, SortedOnAccess>/Sor...         10
# 27   LookUpFixture<std::vector, SortedOnAccess>/Sor...         11
# 28   LookUpFixture<std::vector, SortedOnAccess>/Sor...         12
# 29   LookUpFixture<std::vector, SortedOnAccess>/Sor...         13
# ..                                                 ...        ...
# 96   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...         17
# 97   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...         18
# 98   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...         19
# 99   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...         20
# 100  LookUpFixture<std::list, SortedOnAccess>/Sorte...          0
# 101  LookUpFixture<std::list, SortedOnAccess>/Sorte...          1
# 102  LookUpFixture<std::list, SortedOnAccess>/Sorte...          2
# 103  LookUpFixture<std::list, SortedOnAccess>/Sorte...          3
# 104  LookUpFixture<std::list, SortedOnAccess>/Sorte...          4
# 105  LookUpFixture<std::list, SortedOnAccess>/Sorte...          5
# 106  LookUpFixture<std::list, SortedOnAccess>/Sorte...          6
# 107  LookUpFixture<std::list, SortedOnAccess>/Sorte...          7
# 108  LookUpFixture<std::list, SortedOnAccess>/Sorte...          8
# 109  LookUpFixture<std::list, SortedOnAccess>/Sorte...          9
# 110  LookUpFixture<std::list, SortedOnAccess>/Sorte...         10
# 111  LookUpFixture<std::list>/UnsortedList_LookUp/1...          0
# 112  LookUpFixture<std::list>/UnsortedList_LookUp/1...          1
# 113  LookUpFixture<std::list>/UnsortedList_LookUp/1...          2
# 114  LookUpFixture<std::list>/UnsortedList_LookUp/1...          3
# 115  LookUpFixture<std::list>/UnsortedList_LookUp/1...          4
# 116  LookUpFixture<std::list>/UnsortedList_LookUp/1...          5
# 117  LookUpFixture<std::list>/UnsortedList_LookUp/1...          6
# 118  LookUpFixture<std::list>/UnsortedList_LookUp/1...          7
# 119  LookUpFixture<std::list>/UnsortedList_LookUp/1...          8
# 120  LookUpFixture<std::list>/UnsortedList_LookUp/1...          9
# 121  LookUpFixture<std::list>/UnsortedList_LookUp/1...         10
# 122  LookUpFixture<std::list>/UnsortedList_LookUp/1...         11
# 123  LookUpFixture<std::list>/UnsortedList_LookUp/1...         12
# 124  LookUpFixture<std::list>/UnsortedList_LookUp/1...         13
# 125  LookUpFixture<std::list>/UnsortedList_LookUp/1...         14
#
#         real_time  repetition_index  repetitions  \
# 0        0.034080                 0            1
# 1        0.350810                 0            1
# 2        3.399793                 0            1
# 3        0.282247                 0            1
# 4        2.947735                 0            1
# 5       28.011406                 0            1
# 6        2.771730                 0            1
# 7       27.491616                 0            1
# 8      283.948208                 0            1
# 9       33.785649                 0            1
# 10     332.251246                 0            1
# 11    3351.520579                 0            1
# 12     350.714720                 0            1
# 13    3791.888051                 0            1
# 14   36393.424727                 0            1
# 15    7257.846067                 0            1
# 16       0.008369                 0            1
# 17       0.089969                 0            1
# 18       0.849122                 0            1
# 19       0.017750                 0            1
# 20       0.182634                 0            1
# 21       1.809090                 0            1
# 22       0.025167                 0            1
# 23       0.251353                 0            1
# 24       2.420444                 0            1
# 25       0.091382                 0            1
# 26       0.923931                 0            1
# 27       8.942679                 0            1
# 28       0.154586                 0            1
# 29       1.514026                 0            1
# ..            ...               ...          ...
# 96      14.948401                 0            1
# 97       0.022450                 0            1
# 98       0.226623                 0            1
# 99      11.977283                 0            1
# 100      0.227021                 0            1
# 101      2.335629                 0            1
# 102     22.505423                 0            1
# 103      3.419818                 0            1
# 104     34.741189                 0            1
# 105    338.501194                 0            1
# 106    155.220167                 0            1
# 107   1495.506615                 0            1
# 108  15681.200524                 0            1
# 109   3020.038182                 0            1
# 110  28461.903365                 0            1
# 111      0.114081                 0            1
# 112      1.296110                 0            1
# 113     11.475816                 0            1
# 114      1.617706                 0            1
# 115     16.360492                 0            1
# 116    163.592886                 0            1
# 117     18.519509                 0            1
# 118    200.967638                 0            1
# 119   1824.825885                 0            1
# 120    176.030423                 0            1
# 121   1754.147152                 0            1
# 122  17928.488929                 0            1
# 123   3361.913105                 0            1
# 124  31665.166138                 0            1
# 125  34206.228896                 0            1
#
#                                               run_name   run_type  threads  \
# 0    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 1    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 2    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 3    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 4    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 5    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 6    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 7    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 8    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 9    LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 10   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 11   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 12   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 13   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 14   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 15   LookUpFixture<std::vector>/UnsortedVec_LookUp/...  iteration        1
# 16   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 17   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 18   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 19   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 20   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 21   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 22   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 23   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 24   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 25   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 26   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 27   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 28   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# 29   LookUpFixture<std::vector, SortedOnAccess>/Sor...  iteration        1
# ..                                                 ...        ...      ...
# 96   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...  iteration        1
# 97   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...  iteration        1
# 98   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...  iteration        1
# 99   LookUpFixture<HashSetWrapper>/HashSet_LookUp/1...  iteration        1
# 100  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 101  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 102  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 103  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 104  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 105  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 106  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 107  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 108  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 109  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 110  LookUpFixture<std::list, SortedOnAccess>/Sorte...  iteration        1
# 111  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 112  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 113  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 114  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 115  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 116  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 117  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 118  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 119  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 120  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 121  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 122  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 123  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 124  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
# 125  LookUpFixture<std::list>/UnsortedList_LookUp/1...  iteration        1
#
#     time_unit
# 0          ms
# 1          ms
# 2          ms
# 3          ms
# 4          ms
# 5          ms
# 6          ms
# 7          ms
# 8          ms
# 9          ms
# 10         ms
# 11         ms
# 12         ms
# 13         ms
# 14         ms
# 15         ms
# 16         ms
# 17         ms
# 18         ms
# 19         ms
# 20         ms
# 21         ms
# 22         ms
# 23         ms
# 24         ms
# 25         ms
# 26         ms
# 27         ms
# 28         ms
# 29         ms
# ..        ...
# 96         ms
# 97         ms
# 98         ms
# 99         ms
# 100        ms
# 101        ms
# 102        ms
# 103        ms
# 104        ms
# 105        ms
# 106        ms
# 107        ms
# 108        ms
# 109        ms
# 110        ms
# 111        ms
# 112        ms
# 113        ms
# 114        ms
# 115        ms
# 116        ms
# 117        ms
# 118        ms
# 119        ms
# 120        ms
# 121        ms
# 122        ms
# 123        ms
# 124        ms
# 125        ms
#
# [126 rows x 12 columns]
